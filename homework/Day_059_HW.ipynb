# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
from sklearn import datasets

digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

# %%
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  1., 10., ..., 10.,  9.,  0.],
#        [ 0.,  0., 15., ...,  6.,  2.,  0.],
#        [ 0.,  0.,  6., ...,  6.,  0.,  0.]])

# %% [markdown]
# 載入 相關套件 並 執行 PCA 實驗 ...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 3)
X = pca.fit_transform(X)

# %%
X
# Out:
# array([[ 28.47993992,  -3.43359358,   1.03184844],
#        [-22.59666568,  17.80122273,   6.11085598],
#        [ -8.83188035,  11.46680511,   2.01624717],
#        ...,
#        [-22.05029473, -16.58404599,  -5.73396936],
#        [-16.44102253, -17.48311968,  -3.95362941],
#        [ 28.5723742 ,   1.03814293,   5.45381191]])

# %%
import numpy as np
unique, counts = np.unique(y, return_counts=True)

print(np.asarray((unique, counts)).T)
# Out:
# [[  0 178]
#  [  1 182]
#  [  2 177]]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()


for name, label in [('0', 0), ('1', 1), ('2', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
color = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()

# %%
fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()


for label in range(0,3):
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean()+6 ,
              X[y == label, 2].mean(), label,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
color = np.choose(y, [0, 1, 2]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
